# %%
my_dict={2:3}
my_dict[1] = 10
my_dict['abc'] = 'def'
my_dict[0] = [0,1,2]
my_dict[1] += 5
my_dict[0].append(3)
my_dict[0].remove(0)
my_dict.pop('abc')
print(my_dict)
# Out:
# {2: 3, 1: 15, 0: [1, 2, 3]}
